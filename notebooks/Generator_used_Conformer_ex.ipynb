# %%
import torch
import torch.nn as nn
from torchsummary import summary
import librosa

import math
import sys
import time
from pathlib import Path
from IPython.display import Audio

from conformer import ConformerBlock

# %%
# model = nn.Sequential(
#     ConformerBlock(dim=64),
#     nn.Conv1d(16, 32, 1),
#     nn.Upsample(scale_factor=2)
# )

# summary(model, (16, 64))

# %%
# x = torch.randn(1, 16, 64)
# output = model(x)
# print(output.shape)

# %%
# def upscale(x, H, W):
#     B, N, C = x.size()
#     assert N == H*W
#     x = x.permute(0, 2, 1)
#     x = x.view(-1, C, H, W)
#     x = nn.PixelShuffle(2)(x)
#     B, C, H, W = x.size()
#     x = x.view(-1, C, H*W)
#     x = x.permute(0, 2, 1)
#     return x, H, W

# %%
def upconv(x, in_channel, out_channel):
    x = x.permute(0, 2, 1)
    print('upconv permuted: ', x.shape)
    x = nn.Conv1d(in_channel, out_channel, 1)(x)
    print('conv1d: ', x.shape)
    x = nn.Upsample(scale_factor=4)(x)
    print('upsample: ', x.shape)
    output = x.permute(0, 2, 1)
    
    return output

# %%
class Generator(nn.Module):
    def __init__(self, latent_dim=100, embed_dim=16, wave_length=int(22050/4)):
        super(Generator, self).__init__()

        self.latent_dim = latent_dim
        self.wave_length = wave_length
        self.embed_dim = embed_dim

        self.l1 = nn.Linear(latent_dim, wave_length * embed_dim)

        self.blocks = nn.ModuleList([
            ConformerBlock(dim=embed_dim),
            # ConformerBlock(dim=embed_dim),
            # ConformerBlock(dim=embed_dim),
            # ConformerBlock(dim=embed_dim),
            # ConformerBlock(dim=embed_dim),
        ])

        self.upsample_blocks = nn.ModuleList([
            nn.ModuleList([
                ConformerBlock(dim=embed_dim//4),
                # ConformerBlock(dim=embed_dim//4),
                # ConformerBlock(dim=embed_dim//4),
                # ConformerBlock(dim=embed_dim//4),
            ]),
            nn.ModuleList([
                ConformerBlock(dim=embed_dim//16),
                # ConformerBlock(dim=embed_dim//16),
            ])
        ])

#         self.deconv = nn.Sequential(
#             nn.Conv2d(embed_dim//16, 1, 1, 1, 0)
#         )

    def forward(self, z):
        print("input: ", z.shape)
        x = self.l1(z)
        print("Linear-1:", x.shape)
        x = x.view(-1, self.wave_length, self.embed_dim)
        print("reshape:", x.shape)
        
        for index, blk in enumerate(self.blocks):
            x = blk(x)
            print("Head-ConformerBlock-{}:".format(index), x.shape)
            
        for index, block in enumerate(self.upsample_blocks):
            x = upconv(x, x.size()[2], self.embed_dim//4**(index+1))
            print("upscale-{}:".format(index), x.shape)
            for j, b in enumerate(block):
                x = b(x)
                print("ConformerBlock-{}-{}:".format(index, j), x.shape)
                
        output = x.view(-1)
#         x = x.permute(0, 2, 1)
#         print(x.shape)
#         x = x.view(-1, self.embed_dim//16, H, W)
#         print(x.shape)
#         output = self.deconv(x)

        return output

# %%
model = Generator()

# %%
summary(model, (100, ))
# Out:
# input:  torch.Size([2, 100])
# Linear-1: torch.Size([2, 88192])
# reshape: torch.Size([2, 5512, 16])
# Head-ConformerBlock-0: torch.Size([2, 5512, 16])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-9-4edb5b5fc723> in <module>
# ----> 1 summary(model, (100, ))
#
# ~/Work/ConformerGAN/ConformerGAN_env/lib/python3.8/site-packages/torchsummary/torchsummary.py in summary(model, input_size, batch_size, device)
#      70     # make a forward pass
#      71     # print(x.shape)
# ---> 72     model(*x)
#      73
#      74     # remove these hooks
#
# ~/Work/ConformerGAN/ConformerGAN_env/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# <ipython-input-7-5658e447b3a5> in forward(self, z)
#      51 #             print("upscale-{}:".format(index), x.shape)
#      52             for j, b in enumerate(block):
# ---> 53                 x = b(x)
#      54                 print("ConformerBlock-{}-{}:".format(index, j), x.shape)
#      55
#
# ~/Work/ConformerGAN/ConformerGAN_env/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/Work/ConformerGAN/ConformerGAN_env/lib/python3.8/site-packages/conformer/conformer.py in forward(self, x, mask)
#     202
#     203     def forward(self, x, mask = None):
# --> 204         x = self.ff1(x) + x
#     205         x = self.attn(x, mask = mask) + x
#     206         x = self.conv(x) + x
#
# ~/Work/ConformerGAN/ConformerGAN_env/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/Work/ConformerGAN/ConformerGAN_env/lib/python3.8/site-packages/conformer/conformer.py in forward(self, x, **kwargs)
#      60
#      61     def forward(self, x, **kwargs):
# ---> 62         return self.fn(x, **kwargs) * self.scale
#      63
#      64 class PreNorm(nn.Module):
#
# ~/Work/ConformerGAN/ConformerGAN_env/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/Work/ConformerGAN/ConformerGAN_env/lib/python3.8/site-packages/conformer/conformer.py in forward(self, x, **kwargs)
#      69
#      70     def forward(self, x, **kwargs):
# ---> 71         x = self.norm(x)
#      72         return self.fn(x, **kwargs)
#      73
#
# ~/Work/ConformerGAN/ConformerGAN_env/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/Work/ConformerGAN/ConformerGAN_env/lib/python3.8/site-packages/torch/nn/modules/normalization.py in forward(self, input)
#     168
#     169     def forward(self, input: Tensor) -> Tensor:
# --> 170         return F.layer_norm(
#     171             input, self.normalized_shape, self.weight, self.bias, self.eps)
#     172
#
# ~/Work/ConformerGAN/ConformerGAN_env/lib/python3.8/site-packages/torch/nn/functional.py in layer_norm(input, normalized_shape, weight, bias, eps)
#    2203             layer_norm, (input,), input, normalized_shape, weight=weight, bias=bias, eps=eps
#    2204         )
# -> 2205     return torch.layer_norm(input, normalized_shape, weight, bias, eps, torch.backends.cudnn.enabled)
#    2206
#    2207
#
# RuntimeError: Given normalized_shape=[4], expected input with shape [*, 4], but got input of size[2, 5512, 16]

# %%
latent_dim = 100
z = torch.rand(latent_dim, dtype=torch.float32)
output = model.forward(z)
output = output.squeeze(0).squeeze(0).detach().numpy().copy()

# %%
output.shape
# Out:
# (5632,)

# %%
# S = librosa.feature.inverse.mel_to_stft(output, sr=22050)
# y = librosa.griffinlim(S)
# print(y.shape)
Audio(output, rate=22050)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
S = librosa.feature.inverse.mel_to_stft(output, sr=22050)
y = librosa.griffinlim(S)
print(S.shape)
print(y.shape)
soundfile.write('./output/result.wav', y, 22050, format="WAV")
